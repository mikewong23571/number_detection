# %% [markdown]
# # MNIST Number Detection Demo (PyTorch + UV)\n\n在 Colab 中运行本仓库的手写数字识别 demo。

# %%
import os\n\nREPO_URL = "https://github.com/mikewong23571/number_detection.git"  # 修改为你的仓库地址\nif os.path.exists("number_detection"):\n    !rm -rf number_detection\n!git clone {REPO_URL}\n%cd number_detection

# %%
# !pip install -q uv\n!uv sync

# %%
# 在 GPU (T4) 运行一个快速训练\n!uv run number-detection --epochs 1 --device cuda --max-train-samples 20000 --max-test-samples 5000
